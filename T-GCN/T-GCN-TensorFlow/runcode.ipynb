# %%
import time

# %%
# %%time

# !python main.py
# Out:
# WARNING:tensorflow:From main.py:78: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From main.py:83: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /tf/notebooks/T-GCN/T-GCN/T-GCN-TensorFlow/utils.py:22: The name tf.sparse_reorder is deprecated. Please use tf.sparse.reorder instead.
#
# WARNING:tensorflow:From main.py:62: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From main.py:64: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# ...

# %%
min_rmse:14.16505928656138 min_mae:11.500158 max_acc:0.7588553428649902 r2:-0.04297494888305664 var:-0.02022087574005127
CPU times: user 1min 27s, sys: 21.8 s, total: 1min 49s
Wall time: 1h 22min 22s
